# %% [markdown]
# # Analysing data from Strava
# Following the medium tutorial: https://medium.com/epfl-extension-school/using-the-strava-api-and-python-d93d480490ef
# and the github: https://knanne.github.io/notebooks/visualize_strava_data_in_python.html

# %%
# Fourth time lucky
#from __future__ import print_statement
import time
import swagger_client
from swagger_client.rest import ApiException
from pprint import pprint

# %%
# Configure OAuth2 access token for authorization: strava_oauth
swagger_client.configuration.access_token = 'ec85f4a4d976acff194ac41e6cf0656d5a9940bc' # Get the access code in
# Expires every six hours

# %%
# 'create an instance of the API class'
# Then somehow working with classes
API_Imy = swagger_client.AthletesApi()

# %%
# Exploring the attributes of this class
swagger_client

# %%
swagger_client.__dict__
# Out:
# {'__name__': 'swagger_client',
#  '__doc__': '\n    Strava API v3\n\n    Strava API  # noqa: E501\n\n    OpenAPI spec version: 3.0.0\n    \n    Generated by: https://github.com/swagger-api/swagger-codegen.git\n',
#  '__package__': 'swagger_client',
#  '__loader__': <_frozen_importlib_external.SourceFileLoader at 0x10f49e9b0>,
#  '__spec__': ModuleSpec(name='swagger_client', loader=<_frozen_importlib_external.SourceFileLoader object at 0x10f49e9b0>, origin='/Users/imyyounge/anaconda3/lib/python3.7/site-packages/swagger_client/__init__.py', submodule_search_locations=['/Users/imyyounge/anaconda3/lib/python3.7/site-packages/swagger_client']),
#  '__path__': ['/Users/imyyounge/anaconda3/lib/python3.7/site-packages/swagger_client'],
#  '__file__': '/Users/imyyounge/anaconda3/lib/python3.7/site-packages/swagger_client/__init__.py',
#  '__cached__': '/Users/imyyounge/anaconda3/lib/python3.7/site-packages/swagger_client/__pycache__/__init__.cpython-37.pyc',
#  '__builtins__': {'__name__': 'builtins',
#   '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.",
#   '__package__': '',
#   '__loader__': _frozen_importlib.BuiltinImporter,
#   '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>),
#   '__build_class__': <function __build_class__>,
#   '__import__': <function __import__>,
#   'abs': <function abs(x, /)>,
#   'all': <function all(iterable, /)>,
#   'any': <function any(iterable, /)>,
#   'ascii': <function ascii(obj, /)>,
#   'bin': <function bin(number, /)>,
#   'breakpoint': <function breakpoint>,
#   'callable': <function callable(obj, /)>,
#   'chr': <function chr(i, /)>,
#   'compile': <function compile(source, filename, mode, flags=0, dont_inherit=False, optimize=-1)>,
#   'delattr': <function delattr(obj, name, /)>,
#   'dir': <function dir>,
#   'divmod': <function divmod(x, y, /)>,
#   'eval': <function eval(source, globals=None, locals=None, /)>,
#   'exec': <function exec(source, globals=None, locals=None, /)>,
#   'format': <function format(value, format_spec='', /)>,
#   'getattr': <function getattr>,
#   'globals': <function globals()>,
#   'hasattr': <function hasattr(obj, name, /)>,
#   'hash': <function hash(obj, /)>,
#   'hex': <function hex(number, /)>,
#   'id': <function id(obj, /)>,
#   'input': <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x10f33fd68>>,
#   'isinstance': <function isinstance(obj, class_or_tuple, /)>,
#   'issubclass': <function issubclass(cls, class_or_tuple, /)>,
#   'iter': <function iter>,
#   'len': <function len(obj, /)>,
#   'locals': <function locals()>,
#   'max': <function max>,
#   'min': <function min>,
#   'next': <function next>,
#   'oct': <function oct(number, /)>,
#   'ord': <function ord(c, /)>,
#   'pow': <function pow(x, y, z=None, /)>,
#   'print': <function print>,
#   'repr': <function repr(obj, /)>,
#   'round': <function round(number, ndigits=None)>,
#   'setattr': <function setattr(obj, name, value, /)>,
#   'sorted': <function sorted(iterable, /, *, key=None, reverse=False)>,
#   'sum': <function sum(iterable, start=0, /)>,
#   'vars': <function vars>,
#   'None': None,
#   'Ellipsis': Ellipsis,
#   'NotImplemented': NotImplemented,
#   'False': False,
#   'True': True,
#   'bool': bool,
#   'memoryview': memoryview,
#   'bytearray': bytearray,
#   'bytes': bytes,
#   'classmethod': classmethod,
#   'complex': complex,
#   'dict': dict,
#   'enumerate': enumerate,
#   'filter': filter,
#   'float': float,
#   'frozenset': frozenset,
#   'property': property,
#   'int': int,
#   'list': list,
#   'map': map,
#   'object': object,
#   'range': range,
#   'reversed': reversed,
#   'set': set,
#   'slice': slice,
#   'staticmethod': staticmethod,
#   'str': str,
#   'super': super,
#   'tuple': tuple,
#   'type': type,
#   'zip': zip,
#   '__debug__': True,
#   'BaseException': BaseException,
#   'Exception': Exception,
#   'TypeError': TypeError,
#   'StopAsyncIteration': StopAsyncIteration,
#   'StopIteration': StopIteration,
#   'GeneratorExit': GeneratorExit,
#   'SystemExit': SystemExit,
#   'KeyboardInterrupt': KeyboardInterrupt,
#   'ImportError': ImportError,
#   'ModuleNotFoundError': ModuleNotFoundError,
#   'OSError': OSError,
#   'EnvironmentError': OSError,
#   'IOError': OSError,
#   'EOFError': EOFError,
#   'RuntimeError': RuntimeError,
#   'RecursionError': RecursionError,
#   'NotImplementedError': NotImplementedError,
#   'NameError': NameError,
#   'UnboundLocalError': UnboundLocalError,
#   'AttributeError': AttributeError,
#   'SyntaxError': SyntaxError,
#   'IndentationError': IndentationError,
#   'TabError': TabError,
#   'LookupError': LookupError,
#   'IndexError': IndexError,
#   'KeyError': KeyError,
#   'ValueError': ValueError,
#   'UnicodeError': UnicodeError,
#   'UnicodeEncodeError': UnicodeEncodeError,
#   'UnicodeDecodeError': UnicodeDecodeError,
#   'UnicodeTranslateError': UnicodeTranslateError,
#   'AssertionError': AssertionError,
#   'ArithmeticError': ArithmeticError,
#   'FloatingPointError': FloatingPointError,
#   'OverflowError': OverflowError,
#   'ZeroDivisionError': ZeroDivisionError,
#   'SystemError': SystemError,
#   'ReferenceError': ReferenceError,
#   'MemoryError': MemoryError,
#   'BufferError': BufferError,
#   'Warning': Warning,
#   'UserWarning': UserWarning,
#   'DeprecationWarning': DeprecationWarning,
#   'PendingDeprecationWarning': PendingDeprecationWarning,
#   'SyntaxWarning': SyntaxWarning,
#   'RuntimeWarning': RuntimeWarning,
#   'FutureWarning': FutureWarning,
#   'ImportWarning': ImportWarning,
#   'UnicodeWarning': UnicodeWarning,
#   'BytesWarning': BytesWarning,
#   'ResourceWarning': ResourceWarning,
#   'ConnectionError': ConnectionError,
#   'BlockingIOError': BlockingIOError,
#   'BrokenPipeError': BrokenPipeError,
#   'ChildProcessError': ChildProcessError,
#   'ConnectionAbortedError': ConnectionAbortedError,
#   'ConnectionRefusedError': ConnectionRefusedError,
#   'ConnectionResetError': ConnectionResetError,
#   'FileExistsError': FileExistsError,
#   'FileNotFoundError': FileNotFoundError,
#   'IsADirectoryError': IsADirectoryError,
#   'NotADirectoryError': NotADirectoryError,
#   'InterruptedError': InterruptedError,
#   'PermissionError': PermissionError,
#   'ProcessLookupError': ProcessLookupError,
#   'TimeoutError': TimeoutError,
#   'open': <function io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#   'copyright': Copyright (c) 2001-2019 Python Software Foundation.
#   All Rights Reserved.
#
#   Copyright (c) 2000 BeOpen.com.
#   All Rights Reserved.
#
#   Copyright (c) 1995-2001 Corporation for National Research Initiatives.
#   All Rights Reserved.
#
#   Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
#   All Rights Reserved.,
#   'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#       for supporting Python development.  See www.python.org for more information.,
#   'license': Type license() to see the full license text,
#   'help': Type help() for interactive help, or help(object) for help about object.,
#   '__IPYTHON__': True,
#   'display': <function IPython.core.display.display(*objs, include=None, exclude=None, metadata=None, transient=None, display_id=None, **kwargs)>,
#   'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10e18e630>>},
#  'absolute_import': _Feature((2, 5, 0, 'alpha', 1), (3, 0, 0, 'alpha', 0), 16384),
#  'configuration': <module 'swagger_client.configuration' from '/Users/imyyounge/anaconda3/lib/python3.7/site-packages/swagger_client/configuration.py'>,
#  'models': <module 'swagger_client.models' from '/Users/imyyounge/anaconda3/lib/python3.7/site-packages/swagger_client/models/__init__.py'>,
#  'rest': <module 'swagger_client.rest' from '/Users/imyyounge/anaconda3/lib/python3.7/site-packages/swagger_client/rest.py'>,
#  'api_client': <module 'swagger_client.api_client' from '/Users/imyyounge/anaconda3/lib/python3.7/site-packages/swagger_client/api_client.py'>,
#  'api': <module 'swagger_client.api' from '/Users/imyyounge/anaconda3/lib/python3.7/site-packages/swagger_client/api/__init__.py'>,
#  'ActivitiesApi': swagger_client.api.activities_api.ActivitiesApi,
#  'AthletesApi': swagger_client.api.athletes_api.AthletesApi,
#  'ClubsApi': swagger_client.api.clubs_api.ClubsApi,
#  'GearsApi': swagger_client.api.gears_api.GearsApi,
#  'RoutesApi': swagger_client.api.routes_api.RoutesApi,
#  'RunningRacesApi': swagger_client.api.running_races_api.RunningRacesApi,
#  'SegmentEffortsApi': swagger_client.api.segment_efforts_api.SegmentEffortsApi,
#  'SegmentsApi': swagger_client.api.segments_api.SegmentsApi,
#  'StreamsApi': swagger_client.api.streams_api.StreamsApi,
#  'UploadsApi': swagger_client.api.uploads_api.UploadsApi,
#  'ApiClient': swagger_client.api_client.ApiClient,
#  'Configuration': swagger_client.configuration.Configuration,
#  'ActivityStats': swagger_client.models.activity_stats.ActivityStats,
#  'ActivityTotal': swagger_client.models.activity_total.ActivityTotal,
#  'ActivityType': swagger_client.models.activity_type.ActivityType,
#  'ActivityZone': swagger_client.models.activity_zone.ActivityZone,
#  'BaseStream': swagger_client.models.base_stream.BaseStream,
#  'Comment': swagger_client.models.comment.Comment,
#  'Error': swagger_client.models.error.Error,
#  'ExplorerResponse': swagger_client.models.explorer_response.ExplorerResponse,
#  'ExplorerSegment': swagger_client.models.explorer_segment.ExplorerSegment,
#  'Fault': swagger_client.models.fault.Fault,
#  'HeartRateZoneRanges': swagger_client.models.heart_rate_zone_ranges.HeartRateZoneRanges,
#  'Lap': swagger_client.models.lap.Lap,
#  'LatLng': swagger_client.models.lat_lng.LatLng,
#  'MetaActivity': swagger_client.models.meta_activity.MetaActivity,
#  'MetaAthlete': swagger_client.models.meta_athlete.MetaAthlete,
#  'MetaClub': swagger_client.models.meta_club.MetaClub,
#  'PhotosSummary': swagger_client.models.photos_summary.PhotosSummary,
#  'PhotosSummaryPrimary': swagger_client.models.photos_summary_primary.PhotosSummaryPrimary,
#  'PolylineMap': swagger_client.models.polyline_map.PolylineMap,
#  'PowerZoneRanges': swagger_client.models.power_zone_ranges.PowerZoneRanges,
#  'Route': swagger_client.models.route.Route,
#  'RouteDirection': swagger_client.models.route_direction.RouteDirection,
#  'RunningRace': swagger_client.models.running_race.RunningRace,
#  'SegmentLeaderboard': swagger_client.models.segment_leaderboard.SegmentLeaderboard,
#  'SegmentLeaderboardEntry': swagger_client.models.segment_leaderboard_entry.SegmentLeaderboardEntry,
#  'Split': swagger_client.models.split.Split,
#  'StreamSet': swagger_client.models.stream_set.StreamSet,
#  'SummaryGear': swagger_client.models.summary_gear.SummaryGear,
#  'SummarySegment': swagger_client.models.summary_segment.SummarySegment,
#  'SummarySegmentEffort': swagger_client.models.summary_segment_effort.SummarySegmentEffort,
#  'TimedZoneDistribution': swagger_client.models.timed_zone_distribution.TimedZoneDistribution,
#  'UpdatableActivity': swagger_client.models.updatable_activity.UpdatableActivity,
#  'Upload': swagger_client.models.upload.Upload,
#  'ZoneRange': swagger_client.models.zone_range.ZoneRange,
#  'ZoneRanges': swagger_client.models.zone_ranges.ZoneRanges,
#  'Zones': swagger_client.models.zones.Zones,
#  'AltitudeStream': swagger_client.models.altitude_stream.AltitudeStream,
#  'CadenceStream': swagger_client.models.cadence_stream.CadenceStream,
#  'DetailedGear': swagger_client.models.detailed_gear.DetailedGear,
#  'DetailedSegment': swagger_client.models.detailed_segment.DetailedSegment,
#  'DetailedSegmentEffort': swagger_client.models.detailed_segment_effort.DetailedSegmentEffort,
#  'DistanceStream': swagger_client.models.distance_stream.DistanceStream,
#  'HeartrateStream': swagger_client.models.heartrate_stream.HeartrateStream,
#  'LatLngStream': swagger_client.models.lat_lng_stream.LatLngStream,
#  'MovingStream': swagger_client.models.moving_stream.MovingStream,
#  'PowerStream': swagger_client.models.power_stream.PowerStream,
#  'SmoothGradeStream': swagger_client.models.smooth_grade_stream.SmoothGradeStream,
#  'SmoothVelocityStream': swagger_client.models.smooth_velocity_stream.SmoothVelocityStream,
#  'SummaryActivity': swagger_client.models.summary_activity.SummaryActivity,
#  'SummaryAthlete': swagger_client.models.summary_athlete.SummaryAthlete,
#  'SummaryClub': swagger_client.models.summary_club.SummaryClub,
#  'TemperatureStream': swagger_client.models.temperature_stream.TemperatureStream,
#  'TimeStream': swagger_client.models.time_stream.TimeStream,
#  'TimedZoneRange': swagger_client.models.timed_zone_range.TimedZoneRange,
#  'DetailedActivity': swagger_client.models.detailed_activity.DetailedActivity,
#  'DetailedAthlete': swagger_client.models.detailed_athlete.DetailedAthlete,
#  'DetailedClub': swagger_client.models.detailed_club.DetailedClub}

# %%
try: 
    # Get Authenticated Athlete
    api_response = API_Imy.getLoggedInAthlete()
    pprint(api_response)
except ApiException as e:
    print("Exception when calling AthletesApi->getLoggedInAthlete: %s\n" % e)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-b2707c6c72bc> in <module>
#       1 try:
#       2     # Get Authenticated Athlete
# ----> 3     api_response = API_Imy.getLoggedInAthlete()
#       4     pprint(api_response)
#       5 except ApiException as e:
#
# AttributeError: 'AthletesApi' object has no attribute 'getLoggedInAthlete'

# %% [markdown]
# Adding in stravalib: https://github.com/hozn/stravalib

# %%
# Got the data and created an instance, now need to try and use stravalib with it
import stravalib

# %%
client = stravalib.Client()
access_token = 'ec85f4a4d976acff194ac41e6cf0656d5a9940bc'
AccessToken = 'ec85f4a4d976acff194ac41e6cf0656d5a9940bc'
client.access_token = access_token
refresh_token = '9c58e612618a104c996699783bda5c87758299aa'
client.refresh_token = refresh_token
athlete = client.get_athlete()
print("For {id}, I now have an access token {token}".format(id=athlete.id, token=access_token))
# Out:
# For 45393409, I now have an access token ec85f4a4d976acff194ac41e6cf0656d5a9940bc

# %% [markdown]
# Glimpse at the data that can be exported from strava

# %% [markdown]
# Good website for explaining what can be done with stravalib.

# %%
# Currently-authenticated (based on provided token) athlete
# Will have maximum detail exposed (resource_state=3)
Imy_athlete = client.get_athlete()

# %%
# Get an activity
activity = client.get_activity(1)
# If activity is owned by current user, will have full detail (resource_state=3)
# otherwise summary-level detail.
# Out:
# ---------------------------------------------------------------------------
# ObjectNotFound                            Traceback (most recent call last)
# <ipython-input-31-9abf5562998b> in <module>
#       1 # Get an activity
# ----> 2 activity = client.get_activity(1)
#       3 # If activity is owned by current user, will have full detail (resource_state=3)
#       4 # otherwise summary-level detail.
#
# ~/anaconda3/lib/python3.7/site-packages/stravalib/client.py in get_activity(self, activity_id, include_all_efforts)
#     508         """
#     509         raw = self.protocol.get('/activities/{id}', id=activity_id,
# --> 510                                 include_all_efforts=include_all_efforts)
#     511         return model.Activity.deserialize(raw, bind_client=self)
#     512
#
# ~/anaconda3/lib/python3.7/site-packages/stravalib/protocol.py in get(self, url, check_for_errors, use_webhook_server, **kwargs)
#     297         url = url.format(**kwargs)
#     298         params = dict([(k, v) for k, v in kwargs.items() if not k in referenced])
# --> 299         return self._request(url, params=params, check_for_errors=check_for_errors, use_webhook_server=use_webhook_server)
#     300
#     301     def post(self, url, files=None, check_for_errors=True, use_webhook_server=False, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/stravalib/protocol.py in _request(self, url, params, files, method, check_for_errors, use_webhook_server)
#     219
#     220         if check_for_errors:
# --> 221             self._handle_protocol_error(raw)
#     222
#     223         # 204 = No content
#
# ~/anaconda3/lib/python3.7/site-packages/stravalib/protocol.py in _handle_protocol_error(self, response)
#     266
#     267         if exc_class is not None:
# --> 268             raise exc_class(msg, response=response)
#     269
#     270         return response
#
# ObjectNotFound: Not Found: Record Not Found: [{'resource': 'Activity', 'field': 'id', 'code': 'invalid'}]

# %%
# Bulk get activities
bulk_activities = client.get_activities(limit=50)
for activity in bulk_activities:
    print(activity)
# Out:
# ---------------------------------------------------------------------------
# AccessUnauthorized                        Traceback (most recent call last)
# <ipython-input-44-1925930edcd2> in <module>
#       1 # Bulk get activities
#       2 bulk_activities = client.get_activities(limit=50)
# ----> 3 for activity in bulk_activities:
#       4     print(activity)
#
# ~/anaconda3/lib/python3.7/site-packages/stravalib/client.py in __next__(self)
#    1666
#    1667     def __next__(self):
# -> 1668         return self.next()
#    1669
#    1670     def next(self):
#
# ~/anaconda3/lib/python3.7/site-packages/stravalib/client.py in next(self)
#    1672             self._eof()
#    1673         if not self._buffer:
# -> 1674             self._fill_buffer()
#    1675         try:
#    1676             result = self._buffer.popleft()
#
# ~/anaconda3/lib/python3.7/site-packages/stravalib/client.py in _fill_buffer(self)
#    1643             self._eof()
#    1644
# -> 1645         raw_results = self.result_fetcher(page=self._page, per_page=self.per_page)
#    1646
#    1647         entities = []
#
# ~/anaconda3/lib/python3.7/site-packages/stravalib/protocol.py in get(self, url, check_for_errors, use_webhook_server, **kwargs)
#     297         url = url.format(**kwargs)
#     298         params = dict([(k, v) for k, v in kwargs.items() if not k in referenced])
# --> 299         return self._request(url, params=params, check_for_errors=check_for_errors, use_webhook_server=use_webhook_server)
#     300
#     301     def post(self, url, files=None, check_for_errors=True, use_webhook_server=False, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/stravalib/protocol.py in _request(self, url, params, files, method, check_for_errors, use_webhook_server)
#     219
#     220         if check_for_errors:
# --> 221             self._handle_protocol_error(raw)
#     222
#     223         # 204 = No content
#
# ~/anaconda3/lib/python3.7/site-packages/stravalib/protocol.py in _handle_protocol_error(self, response)
#     266
#     267         if exc_class is not None:
# --> 268             raise exc_class(msg, response=response)
#     269
#     270         return response
#
# AccessUnauthorized: Unauthorized: Authorization Error: [{'resource': 'AccessToken', 'field': 'activity:read_permission', 'code': 'missing'}]

# %%
activity = client.get_activity(2646057263)
print("type = " + activity.type)
# Out:
# ---------------------------------------------------------------------------
# ObjectNotFound                            Traceback (most recent call last)
# <ipython-input-45-a19db6172a8e> in <module>
# ----> 1 activity = client.get_activity(2646057263)
#       2 print("type = " + activity.type)
#
# ~/anaconda3/lib/python3.7/site-packages/stravalib/client.py in get_activity(self, activity_id, include_all_efforts)
#     508         """
#     509         raw = self.protocol.get('/activities/{id}', id=activity_id,
# --> 510                                 include_all_efforts=include_all_efforts)
#     511         return model.Activity.deserialize(raw, bind_client=self)
#     512
#
# ~/anaconda3/lib/python3.7/site-packages/stravalib/protocol.py in get(self, url, check_for_errors, use_webhook_server, **kwargs)
#     297         url = url.format(**kwargs)
#     298         params = dict([(k, v) for k, v in kwargs.items() if not k in referenced])
# --> 299         return self._request(url, params=params, check_for_errors=check_for_errors, use_webhook_server=use_webhook_server)
#     300
#     301     def post(self, url, files=None, check_for_errors=True, use_webhook_server=False, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/stravalib/protocol.py in _request(self, url, params, files, method, check_for_errors, use_webhook_server)
#     219
#     220         if check_for_errors:
# --> 221             self._handle_protocol_error(raw)
#     222
#     223         # 204 = No content
#
# ~/anaconda3/lib/python3.7/site-packages/stravalib/protocol.py in _handle_protocol_error(self, response)
#     266
#     267         if exc_class is not None:
# --> 268             raise exc_class(msg, response=response)
#     269
#     270         return response
#
# ObjectNotFound: Not Found: Resource Not Found: [{'resource': 'Activity', 'field': '', 'code': 'not found'}]
